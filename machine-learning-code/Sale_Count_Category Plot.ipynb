# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("products_sold_category.csv") #import query csv results
data.head()
# Out:
#      category  count
# 0        5367  18648
# 1  8944264011   9546
# 2      171114   7208
# 3  9432902011   5874
# 4  8883853011   4768

# %%
data.plot(x=data.index, y='count')

# %%
count = data['count'].tolist()

# %%
count[0:5]
# Out:
# [18648, 9546, 7208, 5874, 4768]

# %%
plt.figure(figsize=(20,10))
plt.plot(count[0:200])
plt.title('Sale Count per Top 200 Categories',fontsize=24)
plt.xlabel('Ordered Categories',fontsize=20)
plt.ylabel('Sale Count',fontsize=20)
plt.axvline(x=75, color='r', linestyle='--')
plt.axvline(x=20, color='r', linestyle='--')
